# %%
import academictorrents as at
path_of_dataset = at.get("") # Download mnist dataset
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import academictorrents as at
#       2 path_of_dataset = at.get("") # Download mnist dataset
#
# File c:\Users\eddie\AppData\Local\Programs\Python\Python311\Lib\site-packages\academictorrents\__init__.py:1
# ----> 1 from .academictorrents import get, set_datastore
#       2 from .cli import cli
#       3 from .version import __version__
#
# File c:\Users\eddie\AppData\Local\Programs\Python\Python311\Lib\site-packages\academictorrents\academictorrents.py:4
#       2 import json
#       3 import os
# ----> 4 from .PieceManager import PieceManager
#       5 from .Torrent import Torrent
#       6 from .Client import Client
#
# File c:\Users\eddie\AppData\Local\Programs\Python\Python311\Lib\site-packages\academictorrents\PieceManager.py:1
# ----> 1 from . import Piece
#       2 import bitstring
# ...
